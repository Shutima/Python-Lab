# %% [markdown]
# ## Using Beautiful soup to take image from the website

# %%
import requests
from requests import get
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import re
url = 'https://www.vinted.fr/femmes'

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# Trying to download new driver from http://chromedriver.storage.googleapis.com/80.0.3987.106/chromedriver_win32.zip
# Unpack archive C:\Users\spoti\.wdm\drivers\chromedriver\80.0.3987.106\win32\chromedriver.zip

# %%
#response = requests.get(url)
#url = 'https://www.vinted.fr/cdn-cgi/beacon/performance?req_id=5703c6cec930cdaf'
#response = get(url)
#print(response.text)

url="https://www.vinted.fr/femmes/robes"
driver.get(url)
html = driver.page_source

# %%
print(html)

# %%
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
image_containers = html_soup.find_all('a', class_ = 'js-item-link')
print(type(image_containers))
print(len(image_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 24

# %%
print(image_containers)
# Out:
# [<a class="media__image-wrapper js-item-link" data-brand="Pronovias" href="/femmes/fetes-and-cocktails/435731285-vestido-de-fiesta-pronovias" style="background-color: #C3CFE4">
# <img alt="Vestido de fiesta Pronovias" class="js-item-thumbnail item-thumbnail lazy-thumbnail __act_as_lazy" data-bumped="false" data-content-source="catalog" data-content-type="item" data-disable-tracking="false" data-item-id="435731285" data-item-owner-id="35357953" data-item-source="c" data-page="1" data-per-page="24" data-src="https://images.vinted.net/thumbs/310x430/06c4e_HZysvaS5573Azvkvm8D35gEd.jpeg?1583244324-5287677c7f8bbb0e24366fd8d81e2599f68d4526" height="430" src="..." style="background-color: #C3CFE4" title="Vestido de fiesta Pronovias" width="310"/>
# </a>, <a class="media__image-wrapper js-item-link" data-brand="Zara" href="/femmes/bottes-hautes/427639611-cuissarde-zara" style="background-color: #C8C6C6">
# ...

# %%
html_soup.div

# %%
html_soup.a

# %%
type(image_containers)
# Out:
# bs4.element.ResultSet

# %%
print(html_soup.prettify())

# %%
html_soup.title
# Out:
# <title>Femmes - Vinted</title>

# %%
html_soup.find_all('a')
# Out:
# [<a class="u-block" data-track-event="user.click" data-track-event-params='{"target":"logo"}' href="https://www.vinted.fr/">
#  <div class="u-ui-padding-left-small">
#  <span class="svg svg--parent-height" style="height: 44px"><svg height="48" viewbox="0 0 83 48" width="83" xmlns="http://www.w3.org/2000/svg">
# ...

# %%
type(response.text)
# Out:
# str

# %%
for m in re.finditer("href=", str(response.text) ):
    print('%02d-%02d: %s' % (m.start(), m.end(), m.group(0)))
for n in re.finditer("style", str(response.text) ):
    print('%02d-%02d: %s' % (n.start(), n.end(), n.group(0)))
# Out:
# 1175-1180: href=
# 1252-1257: href=
# 1329-1334: href=
# 1406-1411: href=
# 1483-1488: href=
# 2141-2146: href=
# 2601-2606: href=
# 2657-2662: href=
# 2989-2994: href=
# 3136-3141: href=
# 3304-3309: href=
# 3469-3474: href=
# 3612-3617: href=
# 23522-23527: href=
# 27286-27291: href=
# 27701-27706: href=
# 27934-27939: href=
# 30973-30978: href=
# 31344-31349: href=
# 31609-31614: href=
# 33015-33020: href=
# 33908-33913: href=
# 34853-34858: href=
# 35556-35561: href=
# 36303-36308: href=
# 36574-36579: href=
# 36833-36838: href=
# 37091-37096: href=
# 37471-37476: href=
# 37723-37728: href=
# 37973-37978: href=
# 38228-38233: href=
# 38613-38618: href=
# 38886-38891: href=
# 39159-39164: href=
# 39438-39443: href=
# 39707-39712: href=
# 40071-40076: href=
# 40421-40426: href=
# 40860-40865: href=
# 42505-42510: href=
# 43765-43770: href=
# 44879-44884: href=
# 45755-45760: href=
# 46593-46598: href=
# 47775-47780: href=
# 48640-48645: href=
# 49232-49237: href=
# ...

# %%
str(response.text)[73:130]
# Out:
# '              /$$\n            | $$   | $$|__/            '

# %%
# Out:
# None
